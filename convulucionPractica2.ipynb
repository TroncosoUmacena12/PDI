# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def convulsion_media_horizontal(imagen, tamañoKernel):
    kernel = np.ones([1, tamañoKernel], np.float32)/tamañoKernel
    img_fin = cv2.filter2D(imagen, -1, kernel)
    return img_fin 

def convulsion_media_vertical(imagen, tamañoKernel):
    kernel = np.ones([tamañoKernel,1], np.float32)/tamañoKernel
    img_fin = cv2.filter2D(imagen, -1, kernel)
    return img_fin 

def convulsion_media_diagonal(imagen, tamañoKernel):
    kernel = np.zeros((tamañoKernel,tamañoKernel), np.float32)
    np.fill_diagonal(kernel, 1.0 / tamañoKernel)
    img_fin = cv2.filter2D(imagen, -1, kernel)
    return img_fin



imagen = cv2.imread('P1.png')
gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)

img_rest = convulsion_media_horizontal(gris,10)
img_rest2 = convulsion_media_vertical(gris,10)
img_rest23 = convulsion_media_diagonal(gris,25) 

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.title('Imagen Original')
plt.imshow(cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB))

plt.subplot(1, 2, 2)
plt.title('Suavizado Horizontal')
plt.imshow(img_rest, cmap='gray')

plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
plt.title('Suavizado Vertical')
plt.imshow(img_rest2, cmap='gray')

plt.subplot(1, 2, 2)
plt.title('Suavizado Diagonal')
plt.imshow(img_rest23, cmap='gray')


plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def convulsion_media_horizontal(imagen, tamañoKernel):
    kernel = np.ones([1, tamañoKernel], np.float32)/tamañoKernel
    img_fin = cv2.filter2D(imagen, -1, kernel)
    return img_fin 

def convulsion_media_vertical(imagen, tamañoKernel):
    kernel = np.ones([tamañoKernel, 1], np.float32)/tamañoKernel
    img_fin = cv2.filter2D(imagen, -1, kernel)
    return img_fin 

def convulsion_media_diagonal(imagen, tamañoKernel):
    kernel = np.zeros((tamañoKernel,tamañoKernel), np.float32)
    np.fill_diagonal(kernel, 1.0 / tamañoKernel)
    img_fin = cv2.filter2D(imagen, -1, kernel)
    return img_fin

imagen = cv2.imread('P2.png')
gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)

img_rest = convulsion_media_horizontal(gris,20)
img_rest2 = convulsion_media_vertical(gris,20)
img_rest23 = convulsion_media_diagonal(gris,25) 

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.title('Imagen Original')
plt.imshow(cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB))

plt.subplot(1, 2, 2)
plt.title('Suavizado Horizontal')
plt.imshow(img_rest, cmap='gray')

plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
plt.title('Suavizado Vertical')
plt.imshow(img_rest2, cmap='gray')

plt.subplot(1, 2, 2)
plt.title('Suavizado Diagonal')
plt.imshow(img_rest23, cmap='gray')


plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def convulsion_media_horizontal(imagen, tamañoKernel):
    kernel = np.ones([1, tamañoKernel], np.float32)/tamañoKernel
    img_fin = cv2.filter2D(imagen, -1, kernel)
    return img_fin 

def convulsion_media_vertical(imagen, tamañoKernel):
    kernel = np.ones([tamañoKernel, 1], np.float32)/tamañoKernel
    img_fin = cv2.filter2D(imagen, -1, kernel)
    return img_fin 

def convulsion_media_diagonal(imagen, tamañoKernel):
    kernel = np.zeros((tamañoKernel,tamañoKernel), np.float32)
    np.fill_diagonal(kernel, 1.0 / tamañoKernel)
    img_fin = cv2.filter2D(imagen, -1, kernel)
    return img_fin

imagen = cv2.imread('P3.png')
gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)

img_rest = convulsion_media_horizontal(gris,9)
img_rest2 = convulsion_media_vertical(gris,9)
img_rest23 = convulsion_media_diagonal(gris,8) 

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.title('Imagen Original')
plt.imshow(cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB))

plt.subplot(1, 2, 2)
plt.title('Suavizado Horizontal')
plt.imshow(img_rest, cmap='gray')

plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
plt.title('Suavizado Vertical')
plt.imshow(img_rest2, cmap='gray')

plt.subplot(1, 2, 2)
plt.title('Suavizado Diagonal')
plt.imshow(img_rest23, cmap='gray')


plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def convulsion_media_horizontal(imagen, tamañoKernel):
    kernel = np.ones([1, tamañoKernel], np.float32) / tamañoKernel
    return cv2.filter2D(imagen, -1, kernel)

def convulsion_media_vertical(imagen, tamañoKernel):
    kernel = np.ones([tamañoKernel, 1], np.float32) / tamañoKernel
    return cv2.filter2D(imagen, -1, kernel)

def convulsion_media_diagonal(imagen, tamañoKernel):
    kernel = np.zeros((tamañoKernel, tamañoKernel), np.float32)
    np.fill_diagonal(kernel, 1.0 / tamañoKernel)
    return cv2.filter2D(imagen, -1, kernel)

def convulsion_media_bidimensional(imagen, tamañoKernel):
    kernel = np.ones((tamañoKernel, tamañoKernel), np.float32) / (tamañoKernel * tamañoKernel)
    return cv2.filter2D(imagen, -1, kernel)

imagen = cv2.imread('P1.png')
gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)

kernel_size = 10
img_horizontal = convulsion_media_horizontal(gris, kernel_size)
img_vertical = convulsion_media_vertical(gris, kernel_size)
img_diagonal = convulsion_media_diagonal(gris, 25)
img_bidimensional = convulsion_media_bidimensional(gris, kernel_size)

plt.figure(figsize=(15, 10))

plt.subplot(2, 3, 1)
plt.title('Imagen Original')
plt.imshow(gris, cmap='gray')
plt.axis('off')

plt.subplot(2, 3, 2)
plt.title('Suavizado Horizontal')
plt.imshow(img_horizontal, cmap='gray')
plt.axis('off')

plt.subplot(2, 3, 3)
plt.title('Suavizado Vertical')
plt.imshow(img_vertical, cmap='gray')
plt.axis('off')

plt.subplot(2, 3, 4)
plt.title('Suavizado Diagonal')
plt.imshow(img_diagonal, cmap='gray')
plt.axis('off')

plt.subplot(2, 3, 5)
plt.title('Suavizado Bidimensional')
plt.imshow(img_bidimensional, cmap='gray')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('2.png')
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#Kernel Robert
robertx = np.array([(-1, 0),(0, 1)]) 
roberty = np.array([(0, -1),(1, 0)])
#Mostrar en x,y
img_robx = cv2.filter2D(img_gray, -1, robertx) 
img_roby = cv2.filter2D(img_gray, -1, roberty)
#Magnitud de Robert
rbg_gMagnitud = np.sqrt(img_robx ** 2 + img_roby ** 2)
rgb_gDireecion = np.arctan2(img_roby, img_robx)  #Simulando un filtro Previtt

#Filtro Previtt
#Kernels
previttx = np.array([(1, 0, -1),(1, 0, -1),(1, 0, -1)]) 
previtty = np.array([(1, 1, 1),(0, 0, 0),(-1, -1, -1)]) 

img_prevx = cv2.filter2D(img_gray, -1, previttx)
img_prevy = cv2.filter2D(img_gray, -1, previtty)

prev_mag = np.sqrt(img_prevx ** 2 + img_prevy ** 2)
prev_dir = np.arctan2(img_prevx , img_prevy)

#Filtro Sobet
#Kerner Sobet
sobetx = np.array([(1, 0, -1),(2, 0, -2),(1, 0, -1)]) 
sobety = np.array([(1, 2, 1),(0, 0, 0),(-1, -2, -1)]) 

img_sobx = cv2.filter2D(img_gray, -1, sobetx)
img_soby = cv2.filter2D(img_gray, -1, sobety)

sobel_gradiente = np.sqrt(img_sobx ** 2 + img_soby ** 2)
sobel_dire = np.arctan2(img_sobx, img_soby)


#Filtro Canny
canny = cv2.Canny(img_gray, 100, 200)

plt.figure(figsize=(12,10))

plt.subplot(3, 3, 1)
plt.imshow(img_gray, cmap='gray')
plt.title('Imagen original')
plt.axis('off')

plt.subplot(3, 3, 2)
plt.imshow(rbg_gMagnitud, cmap='gray')
plt.title('Imagen filtro Robert en Magnitud')
plt.axis('off')

plt.subplot(3, 3, 3)
plt.imshow(prev_mag, cmap='gray')
plt.title('Imagen filtro Previt en Magnitud')
plt.axis('off')

plt.subplot(3, 3, 4)
plt.imshow(sobel_gradiente, cmap='gray')
plt.title('Imagen filtro Sobel en Magnitud')
plt.axis('off')

plt.subplot(3, 3, 5)
plt.imshow(canny, cmap='gray')
plt.title('Imagen filtro Canny ambos')
plt.axis('off')

plt.subplot(3, 3, 6)
plt.imshow(rgb_gDireecion, cmap='gray')
plt.title('Imagen filtro Robert en Direccion')
plt.axis('off')

plt.subplot(3, 3, 7)
plt.imshow(prev_dir, cmap='gray')
plt.title('Imagen filtro Previt en Direccion')
plt.axis('off')

plt.subplot(3, 3, 8)
plt.imshow(sobel_dire, cmap='gray')
plt.title('Imagen filtro Sobel en Direccion')
plt.axis('off')


plt.show()
